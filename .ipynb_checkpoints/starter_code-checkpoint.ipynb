# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import models, layers
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os, os.path, shutil
from keras.preprocessing.image import img_to_array, ImageDataGenerator, array_to_img, load_img

# %%
#open first image as a test 
im = Image.open('data/Blight/Corn_Blight (1).jpg')
arr = np.array(im)

# %%
#prep for creating directories 
blight_dir = 'data/Blight/'
gray_dir = 'data/Gray_Leaf_Spot'
rust_dir = 'data/Common_Rust/'
healthy_dir = 'data/Healthy/'
new_dir = 'split/'

# %%
#grab image names for each type
imgs_blight = [file for file in os.listdir(blight_dir)]
imgs_gray = [file for file in os.listdir(gray_dir)]
imgs_rust = [file for file in os.listdir(rust_dir)]
imgs_healthy = [file for file in os.listdir(healthy_dir)]

# %%
imgs_blight[:5]
# Out:
# ['Corn_Blight (966).jpg',
#  'Corn_Blight (435).JPG',
#  'Corn_Blight (1048).JPG',
#  'Corn_Blight (570).JPG',
#  'Corn_Blight (120).JPG']

# %%
#Check to ensure all images are included
print('# Blight: ', len(imgs_blight))
print('# Gray: ', len(imgs_gray))
print('# Rust: ', len(imgs_rust))
print('# Healthy: ', len(imgs_healthy))
# Out:
# # Blight:  1146
# # Gray:  574
# # Rust:  1306
# # Healthy:  1162

# %%
#os.mkdir(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-7-0d1f8d3cb245> in <module>()
# ----> 1 os.mkdir(new_dir)
#
# FileExistsError: [Errno 17] File exists: 'split/'

# %%
#create variables for new split directories for train/ test/ val
train_folder = os.path.join(new_dir, 'train')
train_blight = os.path.join(train_folder, 'blight')
train_gray = os.path.join(train_folder, 'gray')
train_rust = os.path.join(train_folder, 'rust')
train_healthy = os.path.join(train_folder, 'healthy')

test_folder = os.path.join(new_dir, 'test')
test_blight = os.path.join(test_folder, 'blight')
test_gray = os.path.join(test_folder, 'gray')
test_rust = os.path.join(test_folder, 'rust')
test_healthy = os.path.join(test_folder, 'healthy')

val_folder = os.path.join(new_dir, 'validation')
val_blight = os.path.join(val_folder, 'blight')
val_gray = os.path.join(val_folder, 'gray')
val_rust = os.path.join(val_folder, 'rust')
val_healthy = os.path.join(val_folder, 'healthy')

# %%
# #create directories for splits
# os.mkdir(train_folder)
# os.mkdir(train_blight)
# os.mkdir(train_gray)
# os.mkdir(train_rust)
# os.mkdir(train_healthy)

# os.mkdir(test_folder)
# os.mkdir(test_blight)
# os.mkdir(test_gray)
# os.mkdir(test_rust)
# os.mkdir(test_healthy)

# os.mkdir(val_folder)
# os.mkdir(val_blight)
# os.mkdir(val_gray)
# os.mkdir(val_rust)
# os.mkdir(val_healthy)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-8948489b1115> in <module>()
#       1 #create directories for splits
# ----> 2 os.mkdir(train_folder)
#       3 os.mkdir(train_blight)
#       4 os.mkdir(train_gray)
#       5 os.mkdir(train_rust)
#
# FileExistsError: [Errno 17] File exists: 'split/train'

# %%
#use a 74/13/13 split for train/ test/ val 
print('Number of images to train:')
print('# Blight: ', round(len(imgs_blight)*.74))
print('# Gray: ', round(len(imgs_gray)*.74))
print('# Rust: ', round(len(imgs_rust)*.74))
print('# Healthy: ', round(len(imgs_healthy)*.74))

#use a 74/13/13 split for train/ test/ val 
print('Number of images to test/val:')
print('# Blight: ', round(len(imgs_blight)*.13))
print('# Gray: ', round(len(imgs_gray)*.13))
print('# Rust: ', round(len(imgs_rust)*.13))
print('# Healthy: ', round(len(imgs_healthy)*.13))
# Out:
# Number of images to train:
# # Blight:  848
# # Gray:  425
# # Rust:  966
# # Healthy:  860
# Number of images to test/val:
# # Blight:  149
# # Gray:  75
# # Rust:  170
# # Healthy:  151

# %%
# train blight
imgs = imgs_blight[:848]
for img in imgs:
    origin = os.path.join(blight_dir, img)
    destination = os.path.join(train_blight, img)
    shutil.copyfile(origin, destination)
    
# train grey
imgs = imgs_gray[:425]
for img in imgs:
    origin = os.path.join(gray_dir, img)
    destination = os.path.join(train_gray, img)
    shutil.copyfile(origin, destination)
    
# train rust
imgs = imgs_rust[:966]
for img in imgs:
    origin = os.path.join(rust_dir, img)
    destination = os.path.join(train_rust, img)
    shutil.copyfile(origin, destination)
    
# train healthy
imgs = imgs_healthy[:860]
for img in imgs:
    origin = os.path.join(healthy_dir, img)
    destination = os.path.join(train_healthy, img)
    shutil.copyfile(origin, destination)

# %%
# test blight
imgs = imgs_blight[848:997]
for img in imgs:
    origin = os.path.join(blight_dir, img)
    destination = os.path.join(test_blight, img)
    shutil.copyfile(origin, destination)
    
# test grey
imgs = imgs_gray[425:500]
for img in imgs:
    origin = os.path.join(gray_dir, img)
    destination = os.path.join(test_gray, img)
    shutil.copyfile(origin, destination)
    
# test rust
imgs = imgs_rust[966:1136]
for img in imgs:
    origin = os.path.join(rust_dir, img)
    destination = os.path.join(test_rust, img)
    shutil.copyfile(origin, destination)
    
# test healthy
imgs = imgs_healthy[860:1011]
for img in imgs:
    origin = os.path.join(healthy_dir, img)
    destination = os.path.join(test_healthy, img)
    shutil.copyfile(origin, destination)

# %%
# # val blight
imgs = imgs_blight[997:]
for img in imgs:
    origin = os.path.join(blight_dir, img)
    destination = os.path.join(val_blight, img)
    shutil.copyfile(origin, destination)
    
# val grey
imgs = imgs_gray[500:]
for img in imgs:
    origin = os.path.join(gray_dir, img)
    destination = os.path.join(val_gray, img)
    shutil.copyfile(origin, destination)
    
# val rust
imgs = imgs_rust[1136:]
for img in imgs:
    origin = os.path.join(rust_dir, img)
    destination = os.path.join(val_rust, img)
    shutil.copyfile(origin, destination)
    
# val healthy
imgs = imgs_healthy[1011:]
for img in imgs:
    origin = os.path.join(healthy_dir, img)
    destination = os.path.join(val_healthy, img)
    shutil.copyfile(origin, destination)

# %%
#reshape all images
test_batch = 545
val_batch = 544
train_batch = 3099

# get all test images and reshape 
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder, target_size=(64, 64),
                                                                        batch_size = test_batch) 

# get all validation images and reshape 
val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder, target_size=(64, 64), 
                                                                      batch_size = val_batch)

# get all train images and reshape 
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(train_folder, target_size=(64, 64),
                                                                        batch_size = train_batch)
# Out:
# Found 545 images belonging to 4 classes.
# Found 544 images belonging to 4 classes.
# Found 3099 images belonging to 4 classes.

# %%
#create images/ labels
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
train_images.shape[0]
# Out:
# 3099

# %%
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

#double check shape to make sure all the images are included
print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (3099, 12288)
# (545, 12288)
# (544, 12288)

# %%
#create labels for all three splits
train_y = np.reshape(train_labels[:,0], (3099,1))
test_y = np.reshape(test_labels[:,0], (545,1))
val_y = np.reshape(val_labels[:,0], (544,1))

# %% [markdown]
# ### Baseline Model - No Tuning

# %%
#create a dense layer model as a baseline with 2 hidden layers
np.random.seed(10)
model = models.Sequential()
model.add(layers.Dense(20, activation='relu', input_shape=(12288,)))
model.add(layers.Dense(7, activation='relu'))
model.add(layers.Dense(5, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#choose metrics and fit the model on train data
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=45,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# 69/69 [==============================] - 1s 7ms/step - loss: 0.5117 - accuracy: 0.7363 - val_loss: 0.4509 - val_accuracy: 0.7335
# Epoch 2/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.7411 - val_loss: 0.4332 - val_accuracy: 0.7555
# Epoch 3/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.4348 - accuracy: 0.7640 - val_loss: 0.4390 - val_accuracy: 0.7298
# Epoch 4/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3991 - accuracy: 0.7869 - val_loss: 0.4124 - val_accuracy: 0.7684
# Epoch 5/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.7776 - val_loss: 0.4129 - val_accuracy: 0.7574
# Epoch 6/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8076 - val_loss: 0.4174 - val_accuracy: 0.7555
# Epoch 7/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3855 - accuracy: 0.7940 - val_loss: 0.4657 - val_accuracy: 0.7647
# Epoch 8/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3836 - accuracy: 0.7987 - val_loss: 0.3877 - val_accuracy: 0.8088
# Epoch 9/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8048 - val_loss: 0.4006 - val_accuracy: 0.7757
# Epoch 10/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3717 - accuracy: 0.7956 - val_loss: 0.3860 - val_accuracy: 0.8143
# Epoch 11/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3639 - accuracy: 0.7975 - val_loss: 0.4155 - val_accuracy: 0.7684
# Epoch 12/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8071 - val_loss: 0.3806 - val_accuracy: 0.8070
# Epoch 13/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3687 - accuracy: 0.7973 - val_loss: 0.3758 - val_accuracy: 0.8070
# Epoch 14/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8068 - val_loss: 0.3882 - val_accuracy: 0.8199
# Epoch 15/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3388 - accuracy: 0.8274 - val_loss: 0.4155 - val_accuracy: 0.7849
# Epoch 16/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8312 - val_loss: 0.3999 - val_accuracy: 0.7904
# Epoch 17/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3506 - accuracy: 0.8194 - val_loss: 0.4066 - val_accuracy: 0.8051
# Epoch 18/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3568 - accuracy: 0.8052 - val_loss: 0.3920 - val_accuracy: 0.8015
# Epoch 19/50
# 69/69 [==============================] - 0s 4ms/step - loss: 0.3384 - accuracy: 0.8191 - val_loss: 0.3786 - val_accuracy: 0.8088
# Epoch 20/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.8205 - val_loss: 0.4137 - val_accuracy: 0.7904
# Epoch 21/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3545 - accuracy: 0.8110 - val_loss: 0.3741 - val_accuracy: 0.8235
# Epoch 22/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3329 - accuracy: 0.8216 - val_loss: 0.3730 - val_accuracy: 0.8272
# Epoch 23/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3426 - accuracy: 0.8265 - val_loss: 0.3752 - val_accuracy: 0.8254
# Epoch 24/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3343 - accuracy: 0.8247 - val_loss: 0.3667 - val_accuracy: 0.8217
# Epoch 25/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3190 - accuracy: 0.8397 - val_loss: 0.3705 - val_accuracy: 0.8327
# Epoch 26/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3346 - accuracy: 0.8209 - val_loss: 0.3769 - val_accuracy: 0.8143
# Epoch 27/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8258 - val_loss: 0.3647 - val_accuracy: 0.8180
# Epoch 28/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3308 - accuracy: 0.8304 - val_loss: 0.4165 - val_accuracy: 0.7831
# Epoch 29/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3353 - accuracy: 0.8215 - val_loss: 0.3701 - val_accuracy: 0.8125
# Epoch 30/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3122 - accuracy: 0.8382 - val_loss: 0.3709 - val_accuracy: 0.8125
# Epoch 31/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.8386 - val_loss: 0.3640 - val_accuracy: 0.8217
# Epoch 32/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3251 - accuracy: 0.8332 - val_loss: 0.3641 - val_accuracy: 0.8107
# Epoch 33/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2989 - accuracy: 0.8499 - val_loss: 0.3815 - val_accuracy: 0.8051
# Epoch 34/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2957 - accuracy: 0.8536 - val_loss: 0.3685 - val_accuracy: 0.8254
# Epoch 35/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3210 - accuracy: 0.8278 - val_loss: 0.3575 - val_accuracy: 0.8290
# Epoch 36/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.8504 - val_loss: 0.4335 - val_accuracy: 0.7500
# Epoch 37/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8321 - val_loss: 0.3730 - val_accuracy: 0.8125
# Epoch 38/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.8478 - val_loss: 0.3630 - val_accuracy: 0.8199
# Epoch 39/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2872 - accuracy: 0.8534 - val_loss: 0.3771 - val_accuracy: 0.8107
# Epoch 40/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2801 - accuracy: 0.8648 - val_loss: 0.3577 - val_accuracy: 0.8217
# Epoch 41/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8423 - val_loss: 0.3561 - val_accuracy: 0.8254
# Epoch 42/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.3009 - accuracy: 0.8477 - val_loss: 0.3489 - val_accuracy: 0.8235
# Epoch 43/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2786 - accuracy: 0.8576 - val_loss: 0.3753 - val_accuracy: 0.8143
# Epoch 44/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2867 - accuracy: 0.8596 - val_loss: 0.3781 - val_accuracy: 0.8143
# Epoch 45/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2819 - accuracy: 0.8567 - val_loss: 0.3463 - val_accuracy: 0.8235
# Epoch 46/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2667 - accuracy: 0.8640 - val_loss: 0.3570 - val_accuracy: 0.8254
# Epoch 47/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8705 - val_loss: 0.3390 - val_accuracy: 0.8309
# Epoch 48/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2632 - accuracy: 0.8652 - val_loss: 0.3611 - val_accuracy: 0.8217
# Epoch 49/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8687 - val_loss: 0.3766 - val_accuracy: 0.8346
# Epoch 50/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2532 - accuracy: 0.8739 - val_loss: 0.5887 - val_accuracy: 0.6562

# %%
def viz_train_res(results):
    history = results.history
    plt.figure()
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure()
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()
    
viz_train_res(history)

# %% [markdown]
# ### Model 2 - Adam Optimizer

# %%
np.random.seed(10)
model2 = models.Sequential()
model2.add(layers.Dense(20, activation='relu', input_shape=(12288,)))
model2.add(layers.Dense(7, activation='relu'))
model2.add(layers.Dense(5, activation='relu'))
model2.add(layers.Dense(4, activation='sigmoid'))

# %%
#choose metrics and fit the model on train data
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model2.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=45,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-e41a8d23b9ec> in <module>()
#       6                     epochs=50,
#       7                     batch_size=45,
# ----> 8                     validation_data=(val_img, val_y))
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:788 run_step  **
#         outputs = model.train_step(data)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:756 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/compile_utils.py:203 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:152 __call__
#         losses = call_fn(y_true, y_pred)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:256 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:1608 binary_crossentropy
#         K.binary_crossentropy(y_true, y_pred, from_logits=from_logits), axis=-1)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:4979 binary_crossentropy
#         return nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:174 sigmoid_cross_entropy_with_logits
#         (logits.get_shape(), labels.get_shape()))
#
#     ValueError: logits and labels must have the same shape ((None, 4) vs (None, 1))

# %%
viz_train_res(history)

# %% [markdown]
# ### Model 3 - Categorical Crossentropy

# %%
#create a dense layer model as a baseline with 2 hidden layers
np.random.seed(10)
model3 = models.Sequential()
model3.add(layers.Dense(20, activation='relu', input_shape=(12288,)))
model3.add(layers.Dense(7, activation='relu'))
model3.add(layers.Dense(5, activation='relu'))
model3.add(layers.Dense(4, activation='sigmoid'))

# %%
#choose metrics and fit the model on train data
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model3.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=45,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-59b941be7342> in <module>()
#       6                     epochs=50,
#       7                     batch_size=45,
# ----> 8                     validation_data=(val_img, val_y))
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:788 run_step  **
#         outputs = model.train_step(data)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:756 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/compile_utils.py:203 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:152 __call__
#         losses = call_fn(y_true, y_pred)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:256 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/losses.py:1537 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:4833 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 1) and (None, 4) are incompatible

# %%
viz_train_res(history)

# %% [markdown]
# ### Model 4 - Softmax Output Layer

# %%
#create a dense layer model as a baseline with 2 hidden layers
np.random.seed(10)
model4 = models.Sequential()
model4.add(layers.Dense(20, activation='relu', input_shape=(12288,)))
model4.add(layers.Dense(7, activation='relu'))
model4.add(layers.Dense(5, activation='relu'))
model4.add(layers.Dense(1, activation='softmax'))

# %%
#choose metrics and fit the model on train data
model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model4.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=45,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# 69/69 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.2625 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 2/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2696 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 3/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2751 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 4/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2674 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 5/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2772 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 6/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2721 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 7/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2882 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 8/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2938 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 9/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2795 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 10/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2716 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 11/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2661 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 12/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2700 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 13/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2669 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 14/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2638 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 15/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2650 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 16/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2704 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 17/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2813 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 18/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2738 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 19/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2767 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 20/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2811 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 21/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2713 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 22/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2785 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 23/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2759 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 24/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2558 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 25/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2742 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 26/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2691 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 27/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2776 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 28/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2654 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 29/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2827 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 30/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2755 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 31/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2854 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 32/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2645 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 33/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2771 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 34/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2756 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 35/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2689 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 36/50
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.2673 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 37/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2836 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 38/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2727 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 39/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2683 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 40/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2750 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 41/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2754 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 42/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2745 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 43/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2642 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 44/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2636 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 45/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2771 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 46/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2763 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 47/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2854 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 48/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2700 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 49/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2771 - val_loss: 0.0000e+00 - val_accuracy: 0.2739
# Epoch 50/50
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.2721 - val_loss: 0.0000e+00 - val_accuracy: 0.2739

# %%
viz_train_res(history)
