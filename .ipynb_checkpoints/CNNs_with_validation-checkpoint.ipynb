# %%
def train_CNN(train_directory,target_size=(200,200), classes=None,
              batch_size=128,num_epochs=30,num_classes=5,verbose=0):
    """
    Trains a conv net for the flowers dataset with a 5-class classifiction output
    Also provides suitable arguments for extending it to other similar apps
    
    Arguments:
            train_directory: The directory where the training images are stored in separate folders.
                            These folders should be named as per the classes.
            target_size: Target size for the training images. A tuple e.g. (200,200)
            classes: A Python list with the classes 
            batch_size: Batch size for training
            num_epochs: Number of epochs for training
            num_classes: Number of output classes to consider
            verbose: Verbosity level of the training, passed on to the `fit_generator` method
    Returns:
            A trained conv net model
    
    """
    from tensorflow.keras.preprocessing.image import ImageDataGenerator
    import tensorflow as tf
    from tensorflow.keras.optimizers import RMSprop
    
    # ImageDataGenerator object instance with scaling
    train_datagen = ImageDataGenerator(rescale=1/255,
                                       validation_split=0.2)

    # Flow training images in batches using the generator
    train_generator = train_datagen.flow_from_directory(
            train_directory,  # This is the source directory for training images
            target_size=target_size,  # All images will be resized to 200 x 200
            batch_size=batch_size,
            # Specify the classes explicitly
            classes = classes,
            # Since we use categorical_crossentropy loss, we need categorical labels
            class_mode='categorical',
            subset='training')
    
    validation_generator = train_datagen.flow_from_directory(
            train_directory,  # This is the source directory for training images
            target_size=target_size,  # All images will be resized to 200 x 200
            batch_size=batch_size,
            # Specify the classes explicitly
            classes = classes,
            # Since we use categorical_crossentropy loss, we need categorical labels
            class_mode='categorical',
            subset='validation')
    
    input_shape = tuple(list(target_size)+[3])
    
    # Model architecture
    model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 200x 200 with 3 bytes color
    # The first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=input_shape),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a dense layer
    tf.keras.layers.Flatten(),
    # 512 neuron in the fully-connected layer
    tf.keras.layers.Dense(512, activation='relu'),
    # 5 output neurons for 5 classes with the softmax activation
    tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    # Optimizer and compilation
    model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['acc'])
    
    # Total sample count
    total_sample=train_generator.n
    
    # Validation sample count
    val_sample=validation_generator.n
    
    # Training
    model.fit_generator(
        train_generator, 
        steps_per_epoch=int(total_sample/batch_size),
        validation_data = validation_generator,
        validation_steps = int(val_sample/batch_size),
        epochs=num_epochs,
        verbose=verbose)
    
    return model

# %%
train_directory = "./data/"

# %%
trained_model=train_CNN(train_directory=train_directory,classes=['Blight','Common_Rust','Gray_Leaf_Spot', 'Healthy'],
                        num_epochs=30,num_classes=4,verbose=1)
# Out:
# Found 3352 images belonging to 4 classes.
# Found 836 images belonging to 4 classes.
# /Users/dtunnicliffe/anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 26/26 [==============================] - 40s 1s/step - loss: 1.3971 - acc: 0.3616 - val_loss: 0.8407 - val_acc: 0.6315
# Epoch 2/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.9059 - acc: 0.6031 - val_loss: 0.6026 - val_acc: 0.8034
# Epoch 3/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.7601 - acc: 0.7378 - val_loss: 0.4657 - val_acc: 0.8190
# Epoch 4/30
# 26/26 [==============================] - 38s 1s/step - loss: 0.4981 - acc: 0.8015 - val_loss: 0.3600 - val_acc: 0.8411
# Epoch 5/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.5809 - acc: 0.8006 - val_loss: 0.3831 - val_acc: 0.8555
# Epoch 6/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.4082 - acc: 0.8441 - val_loss: 0.3236 - val_acc: 0.8672
# Epoch 7/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.4519 - acc: 0.8387 - val_loss: 0.3426 - val_acc: 0.8438
# Epoch 8/30
# 26/26 [==============================] - 40s 2s/step - loss: 0.3782 - acc: 0.8589 - val_loss: 0.3168 - val_acc: 0.8607
# Epoch 9/30
# 26/26 [==============================] - 39s 1s/step - loss: 0.3291 - acc: 0.8731 - val_loss: 0.2711 - val_acc: 0.8711
# Epoch 10/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.3121 - acc: 0.8820 - val_loss: 0.2740 - val_acc: 0.8880
# Epoch 11/30
# 26/26 [==============================] - 37s 1s/step - loss: 0.3018 - acc: 0.8845 - val_loss: 0.3638 - val_acc: 0.8529
# Epoch 12/30
# 26/26 [==============================] - 39s 1s/step - loss: 0.2618 - acc: 0.8982 - val_loss: 0.7467 - val_acc: 0.7357
# Epoch 13/30
# 26/26 [==============================] - 41s 2s/step - loss: 0.3672 - acc: 0.8709 - val_loss: 0.2823 - val_acc: 0.8789
# Epoch 14/30
# 26/26 [==============================] - 37s 1s/step - loss: 0.2770 - acc: 0.8978 - val_loss: 0.2997 - val_acc: 0.8750
# Epoch 15/30
# 26/26 [==============================] - 38s 1s/step - loss: 0.2432 - acc: 0.9046 - val_loss: 0.2667 - val_acc: 0.9049
# Epoch 16/30
# 26/26 [==============================] - 40s 2s/step - loss: 0.1880 - acc: 0.9291 - val_loss: 0.3821 - val_acc: 0.8711
# Epoch 17/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.3140 - acc: 0.8915 - val_loss: 0.3174 - val_acc: 0.8880
# Epoch 18/30
# 26/26 [==============================] - 38s 1s/step - loss: 0.1702 - acc: 0.9359 - val_loss: 0.3421 - val_acc: 0.8893
# Epoch 19/30
# 26/26 [==============================] - 39s 1s/step - loss: 0.1673 - acc: 0.9374 - val_loss: 0.3657 - val_acc: 0.8841
# Epoch 20/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.1214 - acc: 0.9584 - val_loss: 0.5364 - val_acc: 0.8516
# Epoch 21/30
# 26/26 [==============================] - 37s 1s/step - loss: 0.1345 - acc: 0.9488 - val_loss: 0.3533 - val_acc: 0.8893
# Epoch 22/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.0793 - acc: 0.9723 - val_loss: 0.5960 - val_acc: 0.8398
# Epoch 23/30
# 26/26 [==============================] - 40s 2s/step - loss: 0.1302 - acc: 0.9547 - val_loss: 0.5657 - val_acc: 0.8568
# Epoch 24/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.0974 - acc: 0.9700 - val_loss: 0.6244 - val_acc: 0.8438
# Epoch 25/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.0745 - acc: 0.9825 - val_loss: 0.4989 - val_acc: 0.8854
# Epoch 26/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.1613 - acc: 0.9688 - val_loss: 0.4718 - val_acc: 0.8867
# Epoch 27/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.1397 - acc: 0.9590 - val_loss: 0.5502 - val_acc: 0.8815
# Epoch 28/30
# 26/26 [==============================] - 36s 1s/step - loss: 0.0492 - acc: 0.9848 - val_loss: 0.5496 - val_acc: 0.8802
# Epoch 29/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.0183 - acc: 0.9959 - val_loss: 0.9543 - val_acc: 0.8372
# Epoch 30/30
# 26/26 [==============================] - 35s 1s/step - loss: 0.1740 - acc: 0.9565 - val_loss: 0.7695 - val_acc: 0.8581
